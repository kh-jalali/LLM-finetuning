# %% [markdown]
# # Training

# %% [markdown]
# ## Technically, it's only a few lines of code to run on GPUs (elsewhere, ie. on Lamini).
# ```
# from llama import BasicModelRunner
#
# model = BasicModelRunner("EleutherAI/pythia-410m")
# model.load_data_from_jsonlines("lamini_docs.jsonl", input_key="question", output_key="answer")
# model.train(is_public=True)
#
#
# ```
# 1. Choose base model.
# 2. Load data.
# 3. Train it. Returns a model ID, dashboard, and playground interface.
#
# ### Let's look under the hood at the core code running this! This is the open core of Lamini's `llama` library :)

# %%
import os
import lamini

lamini.api_url = os.getenv("POWERML__PRODUCTION__URL")
lamini.api_key = os.getenv("POWERML__PRODUCTION__KEY")

# %%
import datasets
import tempfile
import logging
import random
import config
import os
import time
import torch
import transformers
import pandas as pd
import jsonlines

from myLLM_utilities import *
from transformers import AutoTokenizer
from transformers import AutoModelForCausalLM
from transformers import TrainingArguments
from transformers import AutoModelForCausalLM


logger = logging.getLogger(__name__)
global_config = None
# Out:
# WARNING:tensorflow:From C:\Users\windows10\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\windows10\anaconda3\Lib\site-packages\torch\cuda\__init__.py:740: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 9020). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ..\c10\cuda\CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() if nvml_count < 0 else nvml_count
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1130, in _LazyModule._get_module(self, module_name)
#    1129 try:
# -> 1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\anaconda3\Lib\site-packages\transformers\training_args.py:73
#      72 if is_torch_tpu_available(check_device=False):
# ---> 73     import torch_xla.core.xla_model as xm
#      75 if is_torch_neuroncore_available(check_device=False):
#      76     # torchrun support
#      77     # https://github.com/pytorch/xla/pull/3609
#
# File ~\anaconda3\Lib\site-packages\torch_xla\__init__.py:1
# ----> 1 raise ImportError("WRONG PACKAGE. Please install the package from Neuron Repository - pip.repos.neuron.amazonaws.com")
#
# ImportError: WRONG PACKAGE. Please install the package from Neuron Repository - pip.repos.neuron.amazonaws.com
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 16
#      14 from transformers import AutoTokenizer
#      15 from transformers import AutoModelForCausalLM
# ---> 16 from transformers import TrainingArguments
#      17 from transformers import AutoModelForCausalLM
#      20 logger = logging.getLogger(__name__)
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1120, in _LazyModule.__getattr__(self, name)
#    1118     value = self._get_module(name)
#    1119 elif name in self._class_to_module.keys():
# -> 1120     module = self._get_module(self._class_to_module[name])
#    1121     value = getattr(module, name)
#    1122 else:
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1132, in _LazyModule._get_module(self, module_name)
#    1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
# -> 1132     raise RuntimeError(
#    1133         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1134         f" traceback):\n{e}"
#    1135     ) from e
#
# RuntimeError: Failed to import transformers.training_args because of the following error (look up to see its traceback):
# WRONG PACKAGE. Please install the package from Neuron Repository - pip.repos.neuron.amazonaws.com

# %% [markdown]
# ### Load the Lamini docs dataset

# %%
dataset_name = "lamini_docs.jsonl"
dataset_path = f"/content/{dataset_name}"
use_hf = False

# %%
dataset_path = "lamini/lamini_docs"
use_hf = True

# %% [markdown]
# ### Set up the model, training config, and tokenizer

# %%
model_name = "EleutherAI/pythia-410m"

# %%
training_config = {
    "model": {
        "pretrained_name": model_name,
        "max_length" : 2048
    },
    "datasets": {
        "use_hf": use_hf,
        "path": dataset_path
    },
    "verbose": True
}

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
train_dataset, test_dataset = tokenize_and_split_data(training_config, tokenizer)

print(train_dataset)
print(test_dataset)
# Out:
# tokenizer_config.json:   0%|          | 0.00/396 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# 2023-12-29 11:50:06,423 - DEBUG - utilities - Config: datasets.path: lamini/lamini_docs
# datasets.use_hf: true
# model.max_length: 2048
# model.pretrained_name: EleutherAI/pythia-70m
# verbose: true
# tokenize True lamini/lamini_docs
# Downloading readme:   0%|          | 0.00/577 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/615k [00:00<?, ?B/s]
# 2023-12-29 11:50:08,810 - DEBUG - fsspec - <File-like object HfFileSystem, datasets/lamini/lamini_docs@05bd680b81d69a7a1d38193873f1487d73e535bf/data/train-00000-of-00001-5cdebbc48da41394.parquet> read: 0 - 4194304
# 2023-12-29 11:50:08,947 - DEBUG - fsspec - <File-like object HfFileSystem, datasets/lamini/lamini_docs@05bd680b81d69a7a1d38193873f1487d73e535bf/data/train-00000-of-00001-5cdebbc48da41394.parquet> read: 614936 - 4809240
# Downloading data:   0%|          | 0.00/83.7k [00:00<?, ?B/s]
# 2023-12-29 11:50:08,957 - DEBUG - fsspec - <File-like object HfFileSystem, datasets/lamini/lamini_docs@05bd680b81d69a7a1d38193873f1487d73e535bf/data/test-00000-of-00001-4c77a066a883f339.parquet> read: 0 - 4194304
# 2023-12-29 11:50:09,040 - DEBUG - fsspec - <File-like object HfFileSystem, datasets/lamini/lamini_docs@05bd680b81d69a7a1d38193873f1487d73e535bf/data/test-00000-of-00001-4c77a066a883f339.parquet> read: 83671 - 4277975
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/1260 [00:00<?, ? examples/s]
# 2023-12-29 11:50:09,065 - DEBUG - fsspec.local - open file: /home/jovyan/.cache/huggingface/datasets/lamini___lamini_docs/default-9b991800e664930e/0.0.0/0111277fb19b16f696664cde7f0cb90f833dec72db2cc73cfdf87e697f78fe02.incomplete/lamini_docs-train-00000-00000-of-NNNNN.arrow
# Generating test split:   0%|          | 0/140 [00:00<?, ? examples/s]
# 2023-12-29 11:50:09,082 - DEBUG - fsspec.local - open file: /home/jovyan/.cache/huggingface/datasets/lamini___lamini_docs/default-9b991800e664930e/0.0.0/0111277fb19b16f696664cde7f0cb90f833dec72db2cc73cfdf87e697f78fe02.incomplete/lamini_docs-test-00000-00000-of-NNNNN.arrow
# 2023-12-29 11:50:09,086 - DEBUG - fsspec.local - open file: /home/jovyan/.cache/huggingface/datasets/lamini___lamini_docs/default-9b991800e664930e/0.0.0/0111277fb19b16f696664cde7f0cb90f833dec72db2cc73cfdf87e697f78fe02.incomplete/dataset_info.json
# Dataset({
#     features: ['question', 'answer', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 1260
# })
# Dataset({
#     features: ['question', 'answer', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 140
# })

# %% [markdown]
# ### Load the base model

# %%
base_model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/567 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/166M [00:00<?, ?B/s]

# %%
device_count = torch.cuda.device_count()
if device_count > 0:
    logger.debug("Select GPU device")
    device = torch.device("cuda")
else:
    logger.debug("Select CPU device")
    device = torch.device("cpu")
# Out:
# 2023-12-29 11:50:20,928 - DEBUG - __main__ - Select CPU device

# %%
base_model.to(device)
# Out:
# GPTNeoXForCausalLM(
#   (gpt_neox): GPTNeoXModel(
#     (embed_in): Embedding(50304, 512)
#     (emb_dropout): Dropout(p=0.0, inplace=False)
#     (layers): ModuleList(
#       (0-5): 6 x GPTNeoXLayer(
#         (input_layernorm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (post_attention_dropout): Dropout(p=0.0, inplace=False)
#         (post_mlp_dropout): Dropout(p=0.0, inplace=False)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): GPTNeoXRotaryEmbedding()
#           (query_key_value): Linear(in_features=512, out_features=1536, bias=True)
#           (dense): Linear(in_features=512, out_features=512, bias=True)
#           (attention_dropout): Dropout(p=0.0, inplace=False)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=512, out_features=2048, bias=True)
#           (dense_4h_to_h): Linear(in_features=2048, out_features=512, bias=True)
#           (act): GELUActivation()
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (embed_out): Linear(in_features=512, out_features=50304, bias=False)
# )

# %% [markdown]
# ### Define function to carry out inference

# %%
def inference(text, model, tokenizer, max_input_tokens=1000, max_output_tokens=100):
  # Tokenize
  input_ids = tokenizer.encode(
          text,
          return_tensors="pt",
          truncation=True,
          max_length=max_input_tokens
  )

  # Generate
  device = model.device
  generated_tokens_with_prompt = model.generate(
    input_ids=input_ids.to(device),
    max_length=max_output_tokens
  )

  # Decode
  generated_text_with_prompt = tokenizer.batch_decode(generated_tokens_with_prompt, skip_special_tokens=True)

  # Strip the prompt
  generated_text_answer = generated_text_with_prompt[0][len(text):]

  return generated_text_answer

# %% [markdown]
# ### Try the base model

# %%
test_text = test_dataset[0]['question']
print("Question input (test):", test_text)
print(f"Correct answer from Lamini docs: {test_dataset[0]['answer']}")
print("Model's answer: ")
print(inference(test_text, base_model, tokenizer))

# %% [markdown]
# ### Setup training

# %%
max_steps = 90

# %%
trained_model_name = f"lamini_docs_{max_steps}_steps"
output_dir = trained_model_name

# %%
training_args = TrainingArguments(

  # Learning rate
  learning_rate=1.0e-5,

  # Number of training epochs
  num_train_epochs=1,

  # Max steps to train for (each step is a batch of data)
  # Overrides num_train_epochs, if not -1
  max_steps=max_steps,

  # Batch size for training
  per_device_train_batch_size=1,

  # Directory to save model checkpoints
  output_dir=output_dir,

  # Other arguments
  overwrite_output_dir=False, # Overwrite the content of the output directory
  disable_tqdm=False, # Disable progress bars
  eval_steps=120, # Number of update steps between two evaluations
  save_steps=120, # After # steps model is saved
  warmup_steps=1, # Number of warmup steps for learning rate scheduler
  per_device_eval_batch_size=1, # Batch size for evaluation
  evaluation_strategy="steps",
  logging_strategy="steps",
  logging_steps=1,
  optim="adafactor",
  gradient_accumulation_steps = 4,
  gradient_checkpointing=False,

  # Parameters for early stopping
  load_best_model_at_end=True,
  save_total_limit=1,
  metric_for_best_model="eval_loss",
  greater_is_better=False
)

# %%
model_flops = (
  base_model.floating_point_ops(
    {
       "input_ids": torch.zeros(
           (1, training_config["model"]["max_length"])
      )
    }
  )
  * training_args.gradient_accumulation_steps
)

print(base_model)
print("Memory footprint", base_model.get_memory_footprint() / 1e9, "GB")
print("Flops", model_flops / 1e9, "GFLOPs")
# Out:
# GPTNeoXForCausalLM(
#   (gpt_neox): GPTNeoXModel(
#     (embed_in): Embedding(50304, 512)
#     (emb_dropout): Dropout(p=0.0, inplace=False)
#     (layers): ModuleList(
#       (0-5): 6 x GPTNeoXLayer(
#         (input_layernorm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (post_attention_dropout): Dropout(p=0.0, inplace=False)
#         (post_mlp_dropout): Dropout(p=0.0, inplace=False)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): GPTNeoXRotaryEmbedding()
#           (query_key_value): Linear(in_features=512, out_features=1536, bias=True)
#           (dense): Linear(in_features=512, out_features=512, bias=True)
#           (attention_dropout): Dropout(p=0.0, inplace=False)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=512, out_features=2048, bias=True)
#           (dense_4h_to_h): Linear(in_features=2048, out_features=512, bias=True)
#           (act): GELUActivation()
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (embed_out): Linear(in_features=512, out_features=50304, bias=False)
# )
# Memory footprint 0.30687256 GB
# Flops 2195.667812352 GFLOPs

# %%
trainer = Trainer(
    model=base_model,
    model_flops=model_flops,
    total_steps=max_steps,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
)

# %% [markdown]
# ### Train a few steps

# %%
training_output = trainer.train()
# Out:
#     <div>
#
#       <progress value='90' max='90' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [90/90 08:19, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# 2023-12-29 12:26:53,954 - DEBUG - utilities - Step (1) Logs: {'loss': 2.1248, 'learning_rate': 1e-05, 'epoch': 0.0, 'iter_time': 0.0, 'flops': 0.0, 'remaining_time': 0.0}
# 2023-12-29 12:26:59,558 - DEBUG - utilities - Step (2) Logs: {'loss': 1.6038, 'learning_rate': 9.887640449438202e-06, 'epoch': 0.01, 'iter_time': 5.603638410568237, 'flops': 391828960307.47784, 'remaining_time': 493.1201801300049}
# 2023-12-29 12:27:05,159 - DEBUG - utilities - Step (3) Logs: {'loss': 1.4607, 'learning_rate': 9.775280898876405e-06, 'epoch': 0.01, 'iter_time': 5.60231626033783, 'flops': 391921432193.4045, 'remaining_time': 487.4015146493912}
# 2023-12-29 12:27:11,357 - DEBUG - utilities - Step (4) Logs: {'loss': 1.5317, 'learning_rate': 9.662921348314608e-06, 'epoch': 0.01, 'iter_time': 5.801028331120809, 'flops': 378496309106.59216, 'remaining_time': 498.88843647638953}
# 2023-12-29 12:27:17,063 - DEBUG - utilities - Step (5) Logs: {'loss': 1.723, 'learning_rate': 9.55056179775281e-06, 'epoch': 0.02, 'iter_time': 5.777110993862152, 'flops': 380063290230.1463, 'remaining_time': 491.05443447828293}
# 2023-12-29 12:27:22,858 - DEBUG - utilities - Step (6) Logs: {'loss': 1.7306, 'learning_rate': 9.438202247191012e-06, 'epoch': 0.02, 'iter_time': 5.7806977272033695, 'flops': 379827473424.0839, 'remaining_time': 485.57860908508303}
# 2023-12-29 12:27:28,758 - DEBUG - utilities - Step (7) Logs: {'loss': 1.6499, 'learning_rate': 9.325842696629213e-06, 'epoch': 0.02, 'iter_time': 5.800620913505554, 'flops': 378522893512.9752, 'remaining_time': 481.451535820961}
# 2023-12-29 12:27:34,457 - DEBUG - utilities - Step (8) Logs: {'loss': 1.8803, 'learning_rate': 9.213483146067417e-06, 'epoch': 0.03, 'iter_time': 5.786138943263462, 'flops': 379470288197.679, 'remaining_time': 474.4633933476039}
# 2023-12-29 12:27:39,958 - DEBUG - utilities - Step (9) Logs: {'loss': 1.8058, 'learning_rate': 9.101123595505619e-06, 'epoch': 0.03, 'iter_time': 5.750438898801804, 'flops': 381826126838.684, 'remaining_time': 465.7855508029461}
# 2023-12-29 12:27:46,563 - DEBUG - utilities - Step (10) Logs: {'loss': 1.7883, 'learning_rate': 8.988764044943822e-06, 'epoch': 0.03, 'iter_time': 5.845459567175971, 'flops': 375619365273.0644, 'remaining_time': 467.6367653740777}
# 2023-12-29 12:27:52,558 - DEBUG - utilities - Step (11) Logs: {'loss': 1.9066, 'learning_rate': 8.876404494382023e-06, 'epoch': 0.03, 'iter_time': 5.860362243652344, 'flops': 374664179629.8922, 'remaining_time': 462.96861724853517}
# 2023-12-29 12:27:57,562 - DEBUG - utilities - Step (12) Logs: {'loss': 1.5345, 'learning_rate': 8.764044943820226e-06, 'epoch': 0.04, 'iter_time': 5.782531131397594, 'flops': 379707045662.0825, 'remaining_time': 451.0374282490123}
# 2023-12-29 12:28:02,659 - DEBUG - utilities - Step (13) Logs: {'loss': 1.4994, 'learning_rate': 8.651685393258428e-06, 'epoch': 0.04, 'iter_time': 5.725430985291799, 'flops': 383493892074.23956, 'remaining_time': 440.8581858674685}
# 2023-12-29 12:28:08,862 - DEBUG - utilities - Step (14) Logs: {'loss': 1.6633, 'learning_rate': 8.53932584269663e-06, 'epoch': 0.04, 'iter_time': 5.762159402553852, 'flops': 381049474504.0993, 'remaining_time': 437.92411459409277}
# 2023-12-29 12:28:14,360 - DEBUG - utilities - Step (15) Logs: {'loss': 1.6284, 'learning_rate': 8.426966292134832e-06, 'epoch': 0.05, 'iter_time': 5.743272117206028, 'flops': 382302591196.0694, 'remaining_time': 430.74540879045213}
# 2023-12-29 12:28:20,260 - DEBUG - utilities - Step (16) Logs: {'loss': 1.7958, 'learning_rate': 8.314606741573035e-06, 'epoch': 0.05, 'iter_time': 5.753704166412353, 'flops': 381609437824.30853, 'remaining_time': 425.77410831451414}
# 2023-12-29 12:28:25,362 - DEBUG - utilities - Step (17) Logs: {'loss': 1.576, 'learning_rate': 8.202247191011237e-06, 'epoch': 0.05, 'iter_time': 5.713010609149933, 'flops': 384327627334.6015, 'remaining_time': 417.0497744679451}
# 2023-12-29 12:28:30,760 - DEBUG - utilities - Step (18) Logs: {'loss': 1.766, 'learning_rate': 8.08988764044944e-06, 'epoch': 0.06, 'iter_time': 5.694470433627858, 'flops': 385578929233.84174, 'remaining_time': 410.00187122120576}
# 2023-12-29 12:28:36,158 - DEBUG - utilities - Step (19) Logs: {'loss': 1.4806, 'learning_rate': 7.97752808988764e-06, 'epoch': 0.06, 'iter_time': 5.677998900413513, 'flops': 386697470510.62225, 'remaining_time': 403.13792192935944}
# 2023-12-29 12:28:41,560 - DEBUG - utilities - Step (20) Logs: {'loss': 1.8538, 'learning_rate': 7.865168539325843e-06, 'epoch': 0.06, 'iter_time': 5.663443879077309, 'flops': 387691281000.1605, 'remaining_time': 396.4410715354116}
# 2023-12-29 12:28:46,959 - DEBUG - utilities - Step (21) Logs: {'loss': 1.6287, 'learning_rate': 7.752808988764046e-06, 'epoch': 0.07, 'iter_time': 5.650226020812989, 'flops': 388598226737.1446, 'remaining_time': 389.8655954360962}
# 2023-12-29 12:28:52,754 - DEBUG - utilities - Step (22) Logs: {'loss': 1.423, 'learning_rate': 7.640449438202247e-06, 'epoch': 0.07, 'iter_time': 5.657138131913685, 'flops': 388123422330.02075, 'remaining_time': 384.6853929701306}
# 2023-12-29 12:28:58,458 - DEBUG - utilities - Step (23) Logs: {'loss': 1.5829, 'learning_rate': 7.5280898876404495e-06, 'epoch': 0.07, 'iter_time': 5.659247810190374, 'flops': 387978736043.0394, 'remaining_time': 379.1696032827551}
# 2023-12-29 12:29:04,362 - DEBUG - utilities - Step (24) Logs: {'loss': 1.9066, 'learning_rate': 7.415730337078652e-06, 'epoch': 0.08, 'iter_time': 5.66992333660955, 'flops': 387248236351.8068, 'remaining_time': 374.2149402162303}
# 2023-12-29 12:29:09,759 - DEBUG - utilities - Step (25) Logs: {'loss': 2.0459, 'learning_rate': 7.303370786516854e-06, 'epoch': 0.08, 'iter_time': 5.658536970615387, 'flops': 388027474902.79504, 'remaining_time': 367.80490309000015}
# 2023-12-29 12:29:15,057 - DEBUG - utilities - Step (26) Logs: {'loss': 1.7432, 'learning_rate': 7.191011235955056e-06, 'epoch': 0.08, 'iter_time': 5.644126834869385, 'flops': 389018155791.10944, 'remaining_time': 361.22411743164065}
# 2023-12-29 12:29:20,358 - DEBUG - utilities - Step (27) Logs: {'loss': 1.5483, 'learning_rate': 7.078651685393258e-06, 'epoch': 0.09, 'iter_time': 5.630927150066082, 'flops': 389930069034.23224, 'remaining_time': 354.74841045416315}
# 2023-12-29 12:29:25,858 - DEBUG - utilities - Step (28) Logs: {'loss': 2.1427, 'learning_rate': 6.966292134831461e-06, 'epoch': 0.09, 'iter_time': 5.6260602650819, 'flops': 390267382306.4775, 'remaining_time': 348.81573643507784}
# 2023-12-29 12:29:31,862 - DEBUG - utilities - Step (29) Logs: {'loss': 1.9447, 'learning_rate': 6.853932584269663e-06, 'epoch': 0.09, 'iter_time': 5.639572254249027, 'flops': 389332331135.1701, 'remaining_time': 344.0139075091907}
# 2023-12-29 12:29:37,150 - DEBUG - utilities - Step (30) Logs: {'loss': 1.1473, 'learning_rate': 6.741573033707865e-06, 'epoch': 0.1, 'iter_time': 5.627435511556165, 'flops': 390172007807.6609, 'remaining_time': 337.64613069336986}
# 2023-12-29 12:29:42,459 - DEBUG - utilities - Step (31) Logs: {'loss': 1.6163, 'learning_rate': 6.629213483146067e-06, 'epoch': 0.1, 'iter_time': 5.616841125488281, 'flops': 390907943325.72955, 'remaining_time': 331.3936264038086}
# 2023-12-29 12:29:48,458 - DEBUG - utilities - Step (32) Logs: {'loss': 1.6383, 'learning_rate': 6.51685393258427e-06, 'epoch': 0.1, 'iter_time': 5.629161634752827, 'flops': 390052365666.0661, 'remaining_time': 326.49137481566396}
# 2023-12-29 12:29:53,558 - DEBUG - utilities - Step (33) Logs: {'loss': 1.6229, 'learning_rate': 6.404494382022472e-06, 'epoch': 0.1, 'iter_time': 5.612605147063732, 'flops': 391202971671.84064, 'remaining_time': 319.91849338263273}
# 2023-12-29 12:29:58,758 - DEBUG - utilities - Step (34) Logs: {'loss': 1.7051, 'learning_rate': 6.292134831460674e-06, 'epoch': 0.11, 'iter_time': 5.600111802419026, 'flops': 392075710239.1346, 'remaining_time': 313.60626093546546}
# 2023-12-29 12:30:03,862 - DEBUG - utilities - Step (35) Logs: {'loss': 1.9852, 'learning_rate': 6.179775280898876e-06, 'epoch': 0.11, 'iter_time': 5.585528584087596, 'flops': 393099378026.12915, 'remaining_time': 307.2040721248178}
# 2023-12-29 12:30:09,462 - DEBUG - utilities - Step (36) Logs: {'loss': 1.7107, 'learning_rate': 6.06741573033708e-06, 'epoch': 0.11, 'iter_time': 5.585934168951852, 'flops': 393070835771.05536, 'remaining_time': 301.6404451234}
# 2023-12-29 12:30:14,958 - DEBUG - utilities - Step (37) Logs: {'loss': 1.9775, 'learning_rate': 5.955056179775281e-06, 'epoch': 0.12, 'iter_time': 5.583444158236186, 'flops': 393246130905.2678, 'remaining_time': 295.9225403865179}
# 2023-12-29 12:30:21,060 - DEBUG - utilities - Step (38) Logs: {'loss': 2.3809, 'learning_rate': 5.842696629213483e-06, 'epoch': 0.12, 'iter_time': 5.597454747638187, 'flops': 392261824587.04987, 'remaining_time': 291.0676468771857}
# 2023-12-29 12:30:26,562 - DEBUG - utilities - Step (39) Logs: {'loss': 1.8559, 'learning_rate': 5.730337078651685e-06, 'epoch': 0.12, 'iter_time': 5.594934902693096, 'flops': 392438491338.8582, 'remaining_time': 285.3416800373479}
# 2023-12-29 12:30:31,663 - DEBUG - utilities - Step (40) Logs: {'loss': 1.4857, 'learning_rate': 5.617977528089889e-06, 'epoch': 0.13, 'iter_time': 5.582262962292402, 'flops': 393329341018.7776, 'remaining_time': 279.1131481146201}
# 2023-12-29 12:30:37,758 - DEBUG - utilities - Step (41) Logs: {'loss': 1.8534, 'learning_rate': 5.50561797752809e-06, 'epoch': 0.13, 'iter_time': 5.595086532831192, 'flops': 392427856024.7685, 'remaining_time': 274.1592401087284}
# 2023-12-29 12:30:42,862 - DEBUG - utilities - Step (42) Logs: {'loss': 1.5869, 'learning_rate': 5.393258426966292e-06, 'epoch': 0.13, 'iter_time': 5.583117275703244, 'flops': 393269154833.4771, 'remaining_time': 267.9896292337557}
# 2023-12-29 12:30:48,358 - DEBUG - utilities - Step (43) Logs: {'loss': 2.2291, 'learning_rate': 5.280898876404494e-06, 'epoch': 0.14, 'iter_time': 5.5810409386952715, 'flops': 393415464331.8743, 'remaining_time': 262.30892411867774}
# 2023-12-29 12:30:53,557 - DEBUG - utilities - Step (44) Logs: {'loss': 2.0329, 'learning_rate': 5.168539325842698e-06, 'epoch': 0.14, 'iter_time': 5.572167086046796, 'flops': 394041990924.886, 'remaining_time': 256.3196859581526}
# 2023-12-29 12:30:58,850 - DEBUG - utilities - Step (45) Logs: {'loss': 1.8386, 'learning_rate': 5.0561797752809e-06, 'epoch': 0.14, 'iter_time': 5.565808968110518, 'flops': 394492125930.3274, 'remaining_time': 250.4614035649733}
# 2023-12-29 12:31:03,952 - DEBUG - utilities - Step (46) Logs: {'loss': 1.9744, 'learning_rate': 4.943820224719101e-06, 'epoch': 0.15, 'iter_time': 5.5554965813954675, 'flops': 395224401668.24426, 'remaining_time': 244.44184958140056}
# 2023-12-29 12:31:09,850 - DEBUG - utilities - Step (47) Logs: {'loss': 1.7037, 'learning_rate': 4.831460674157304e-06, 'epoch': 0.15, 'iter_time': 5.562953632810841, 'flops': 394694609604.8218, 'remaining_time': 239.20700621086618}
# 2023-12-29 12:31:15,264 - DEBUG - utilities - Step (48) Logs: {'loss': 1.5604, 'learning_rate': 4.719101123595506e-06, 'epoch': 0.15, 'iter_time': 5.559777204026568, 'flops': 394920107726.9477, 'remaining_time': 233.51064256911584}
# 2023-12-29 12:31:20,758 - DEBUG - utilities - Step (49) Logs: {'loss': 2.2389, 'learning_rate': 4.606741573033709e-06, 'epoch': 0.16, 'iter_time': 5.558410629630089, 'flops': 395017201616.5206, 'remaining_time': 227.89483581483364}
# 2023-12-29 12:31:26,861 - DEBUG - utilities - Step (50) Logs: {'loss': 2.7877, 'learning_rate': 4.494382022471911e-06, 'epoch': 0.16, 'iter_time': 5.569525071552822, 'flops': 394228912545.29047, 'remaining_time': 222.78100286211287}
# 2023-12-29 12:31:32,658 - DEBUG - utilities - Step (51) Logs: {'loss': 1.6708, 'learning_rate': 4.382022471910113e-06, 'epoch': 0.16, 'iter_time': 5.574084305763245, 'flops': 393906459233.4602, 'remaining_time': 217.38928792476656}
# 2023-12-29 12:31:37,658 - DEBUG - utilities - Step (52) Logs: {'loss': 1.2729, 'learning_rate': 4.269662921348315e-06, 'epoch': 0.17, 'iter_time': 5.562819985782399, 'flops': 394704092162.5624, 'remaining_time': 211.38715945973115}
# 2023-12-29 12:31:43,651 - DEBUG - utilities - Step (53) Logs: {'loss': 1.9643, 'learning_rate': 4.157303370786518e-06, 'epoch': 0.17, 'iter_time': 5.571093893968142, 'flops': 394117897515.4706, 'remaining_time': 206.13047407682123}
# 2023-12-29 12:31:50,062 - DEBUG - utilities - Step (54) Logs: {'loss': 2.5636, 'learning_rate': 4.04494382022472e-06, 'epoch': 0.17, 'iter_time': 5.586941660575147, 'flops': 392999953417.4422, 'remaining_time': 201.1298997807053}
# 2023-12-29 12:31:55,957 - DEBUG - utilities - Step (55) Logs: {'loss': 1.602, 'learning_rate': 3.932584269662922e-06, 'epoch': 0.17, 'iter_time': 5.5926475480750755, 'flops': 392598995999.2604, 'remaining_time': 195.74266418262764}
# 2023-12-29 12:32:01,053 - DEBUG - utilities - Step (56) Logs: {'loss': 1.6561, 'learning_rate': 3.820224719101124e-06, 'epoch': 0.18, 'iter_time': 5.5836060740730975, 'flops': 393234727382.96466, 'remaining_time': 189.84260651848533}
# 2023-12-29 12:32:06,859 - DEBUG - utilities - Step (57) Logs: {'loss': 2.041, 'learning_rate': 3.707865168539326e-06, 'epoch': 0.18, 'iter_time': 5.58757609128952, 'flops': 392955330984.1864, 'remaining_time': 184.39001101255417}
# 2023-12-29 12:32:13,459 - DEBUG - utilities - Step (58) Logs: {'loss': 2.4367, 'learning_rate': 3.595505617977528e-06, 'epoch': 0.18, 'iter_time': 5.605345244993243, 'flops': 391709647913.872, 'remaining_time': 179.37104783978378}
# 2023-12-29 12:32:19,551 - DEBUG - utilities - Step (59) Logs: {'loss': 2.5108, 'learning_rate': 3.4831460674157306e-06, 'epoch': 0.19, 'iter_time': 5.613736317075532, 'flops': 391124144123.64667, 'remaining_time': 174.0258258293415}
# 2023-12-29 12:32:24,558 - DEBUG - utilities - Step (60) Logs: {'loss': 1.16, 'learning_rate': 3.3707865168539327e-06, 'epoch': 0.19, 'iter_time': 5.603450472072019, 'flops': 391842102164.6142, 'remaining_time': 168.1035141621606}
# 2023-12-29 12:32:30,052 - DEBUG - utilities - Step (61) Logs: {'loss': 1.9979, 'learning_rate': 3.258426966292135e-06, 'epoch': 0.19, 'iter_time': 5.601634379227956, 'flops': 391969140380.52893, 'remaining_time': 162.44739699761072}
# 2023-12-29 12:32:36,058 - DEBUG - utilities - Step (62) Logs: {'loss': 1.7875, 'learning_rate': 3.146067415730337e-06, 'epoch': 0.2, 'iter_time': 5.608254792260342, 'flops': 391506430018.5016, 'remaining_time': 157.0311341832896}
# 2023-12-29 12:32:41,359 - DEBUG - utilities - Step (63) Logs: {'loss': 1.9605, 'learning_rate': 3.03370786516854e-06, 'epoch': 0.2, 'iter_time': 5.6032968067353774, 'flops': 391852848079.13855, 'remaining_time': 151.2890137818552}
# 2023-12-29 12:32:46,358 - DEBUG - utilities - Step (64) Logs: {'loss': 1.6391, 'learning_rate': 2.9213483146067416e-06, 'epoch': 0.2, 'iter_time': 5.593711648668561, 'flops': 392524311272.7525, 'remaining_time': 145.4365028653826}
# 2023-12-29 12:32:51,561 - DEBUG - utilities - Step (65) Logs: {'loss': 2.3876, 'learning_rate': 2.8089887640449444e-06, 'epoch': 0.21, 'iter_time': 5.58760679513216, 'flops': 392953171698.6301, 'remaining_time': 139.690169878304}
# 2023-12-29 12:32:56,959 - DEBUG - utilities - Step (66) Logs: {'loss': 1.4379, 'learning_rate': 2.696629213483146e-06, 'epoch': 0.21, 'iter_time': 5.584685277938843, 'flops': 393158737346.4959, 'remaining_time': 134.03244667053224}
# 2023-12-29 12:33:02,058 - DEBUG - utilities - Step (67) Logs: {'loss': 2.2532, 'learning_rate': 2.584269662921349e-06, 'epoch': 0.21, 'iter_time': 5.577336578658133, 'flops': 393676763341.4482, 'remaining_time': 128.27874130913705}
# 2023-12-29 12:33:08,061 - DEBUG - utilities - Step (68) Logs: {'loss': 1.8803, 'learning_rate': 2.4719101123595505e-06, 'epoch': 0.22, 'iter_time': 5.58367819216714, 'flops': 393229648412.0652, 'remaining_time': 122.84092022767707}
# 2023-12-29 12:33:13,959 - DEBUG - utilities - Step (69) Logs: {'loss': 2.4228, 'learning_rate': 2.359550561797753e-06, 'epoch': 0.22, 'iter_time': 5.588298646842732, 'flops': 392904522665.8573, 'remaining_time': 117.35427158369738}
# 2023-12-29 12:33:19,256 - DEBUG - utilities - Step (70) Logs: {'loss': 1.8313, 'learning_rate': 2.2471910112359554e-06, 'epoch': 0.22, 'iter_time': 5.584089783654696, 'flops': 393200664283.5479, 'remaining_time': 111.68179567309393}
# 2023-12-29 12:33:24,859 - DEBUG - utilities - Step (71) Logs: {'loss': 1.9744, 'learning_rate': 2.1348314606741574e-06, 'epoch': 0.23, 'iter_time': 5.584358361789159, 'flops': 393181753408.91547, 'remaining_time': 106.10280887399401}
# 2023-12-29 12:33:30,262 - DEBUG - utilities - Step (72) Logs: {'loss': 1.8248, 'learning_rate': 2.02247191011236e-06, 'epoch': 0.23, 'iter_time': 5.581805528049737, 'flops': 393361574730.31104, 'remaining_time': 100.47249950489527}
# 2023-12-29 12:33:36,058 - DEBUG - utilities - Step (73) Logs: {'loss': 2.136, 'learning_rate': 1.910112359550562e-06, 'epoch': 0.23, 'iter_time': 5.584779596991009, 'flops': 393152097449.8244, 'remaining_time': 94.94125314884715}
# 2023-12-29 12:33:41,558 - DEBUG - utilities - Step (74) Logs: {'loss': 1.8936, 'learning_rate': 1.797752808988764e-06, 'epoch': 0.23, 'iter_time': 5.583609476481398, 'flops': 393234487762.85754, 'remaining_time': 89.33775162370237}
# 2023-12-29 12:33:47,563 - DEBUG - utilities - Step (75) Logs: {'loss': 2.4692, 'learning_rate': 1.6853932584269663e-06, 'epoch': 0.24, 'iter_time': 5.589300890226622, 'flops': 392834069139.3652, 'remaining_time': 83.83951335339933}
# 2023-12-29 12:33:53,459 - DEBUG - utilities - Step (76) Logs: {'loss': 2.5212, 'learning_rate': 1.5730337078651686e-06, 'epoch': 0.24, 'iter_time': 5.59339469909668, 'flops': 392546553653.1143, 'remaining_time': 78.30752578735353}
# 2023-12-29 12:33:59,861 - DEBUG - utilities - Step (77) Logs: {'loss': 2.603, 'learning_rate': 1.4606741573033708e-06, 'epoch': 0.24, 'iter_time': 5.604031409087934, 'flops': 391801482195.71606, 'remaining_time': 72.85240831814315}
# 2023-12-29 12:34:05,459 - DEBUG - utilities - Step (78) Logs: {'loss': 2.58, 'learning_rate': 1.348314606741573e-06, 'epoch': 0.25, 'iter_time': 5.603954011743719, 'flops': 391806893445.36554, 'remaining_time': 67.24744814092463}
# 2023-12-29 12:34:10,858 - DEBUG - utilities - Step (79) Logs: {'loss': 1.9951, 'learning_rate': 1.2359550561797752e-06, 'epoch': 0.25, 'iter_time': 5.601325297966982, 'flops': 391990769246.86456, 'remaining_time': 61.6145782776368}
# 2023-12-29 12:34:16,162 - DEBUG - utilities - Step (80) Logs: {'loss': 1.9545, 'learning_rate': 1.1235955056179777e-06, 'epoch': 0.25, 'iter_time': 5.597561615931837, 'flops': 392254335549.01263, 'remaining_time': 55.97561615931837}
# 2023-12-29 12:34:22,160 - DEBUG - utilities - Step (81) Logs: {'loss': 2.1733, 'learning_rate': 1.01123595505618e-06, 'epoch': 0.26, 'iter_time': 5.602572190761566, 'flops': 391903528877.7849, 'remaining_time': 50.42314971685409}
# 2023-12-29 12:34:28,262 - DEBUG - utilities - Step (82) Logs: {'loss': 1.9658, 'learning_rate': 8.98876404494382e-07, 'epoch': 0.26, 'iter_time': 5.608733771759787, 'flops': 391472995813.65063, 'remaining_time': 44.869870174078294}
# 2023-12-29 12:34:33,957 - DEBUG - utilities - Step (83) Logs: {'loss': 1.6609, 'learning_rate': 7.865168539325843e-07, 'epoch': 0.26, 'iter_time': 5.609784076853496, 'flops': 391399701355.9817, 'remaining_time': 39.26848853797448}
# 2023-12-29 12:34:39,558 - DEBUG - utilities - Step (84) Logs: {'loss': 1.8634, 'learning_rate': 6.741573033707865e-07, 'epoch': 0.27, 'iter_time': 5.609687089920044, 'flops': 391406468338.9132, 'remaining_time': 33.658122539520264}
# 2023-12-29 12:34:45,459 - DEBUG - utilities - Step (85) Logs: {'loss': 2.6297, 'learning_rate': 5.617977528089888e-07, 'epoch': 0.27, 'iter_time': 5.613151028042748, 'flops': 391164927040.5625, 'remaining_time': 28.06575514021374}
# 2023-12-29 12:34:51,358 - DEBUG - utilities - Step (86) Logs: {'loss': 2.2145, 'learning_rate': 4.49438202247191e-07, 'epoch': 0.27, 'iter_time': 5.616513816048117, 'flops': 390930723980.1134, 'remaining_time': 22.46605526419247}
# 2023-12-29 12:34:57,159 - DEBUG - utilities - Step (87) Logs: {'loss': 2.6152, 'learning_rate': 3.3707865168539325e-07, 'epoch': 0.28, 'iter_time': 5.618657098260036, 'flops': 390781600292.3449, 'remaining_time': 16.855971294780108}
# 2023-12-29 12:35:02,762 - DEBUG - utilities - Step (88) Logs: {'loss': 1.6556, 'learning_rate': 2.247191011235955e-07, 'epoch': 0.28, 'iter_time': 5.618483277572983, 'flops': 390793690018.85913, 'remaining_time': 11.236966555145965}
# 2023-12-29 12:35:08,258 - DEBUG - utilities - Step (89) Logs: {'loss': 2.5383, 'learning_rate': 1.1235955056179776e-07, 'epoch': 0.28, 'iter_time': 5.617092270742763, 'flops': 390890465479.5106, 'remaining_time': 5.617092270742763}
# 2023-12-29 12:35:13,359 - DEBUG - utilities - Step (90) Logs: {'loss': 1.9341, 'learning_rate': 0.0, 'epoch': 0.29, 'iter_time': 5.611285190903739, 'flops': 391294995291.1539, 'remaining_time': 0.0}
# 2023-12-29 12:35:13,360 - DEBUG - utilities - Step (90) Logs: {'train_runtime': 505.1856, 'train_samples_per_second': 0.713, 'train_steps_per_second': 0.178, 'total_flos': 7618098905088.0, 'train_loss': 1.8953344768948026, 'epoch': 0.29, 'iter_time': 5.611295365215687, 'flops': 391294285801.2613, 'remaining_time': 0.0}

# %% [markdown]
# ### Save model locally

# %%
save_dir = f'{output_dir}/final'

trainer.save_model(save_dir)
print("Saved model to:", save_dir)
# Out:
# Saved model to: lamini_docs_90_steps/final

# %%
finetuned_slightly_model = AutoModelForCausalLM.from_pretrained(save_dir, local_files_only=True)

# %%
finetuned_slightly_model.to(device)
# Out:
# GPTNeoXForCausalLM(
#   (gpt_neox): GPTNeoXModel(
#     (embed_in): Embedding(50304, 512)
#     (emb_dropout): Dropout(p=0.0, inplace=False)
#     (layers): ModuleList(
#       (0-5): 6 x GPTNeoXLayer(
#         (input_layernorm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (post_attention_dropout): Dropout(p=0.0, inplace=False)
#         (post_mlp_dropout): Dropout(p=0.0, inplace=False)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): GPTNeoXRotaryEmbedding()
#           (query_key_value): Linear(in_features=512, out_features=1536, bias=True)
#           (dense): Linear(in_features=512, out_features=512, bias=True)
#           (attention_dropout): Dropout(p=0.0, inplace=False)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=512, out_features=2048, bias=True)
#           (dense_4h_to_h): Linear(in_features=2048, out_features=512, bias=True)
#           (act): GELUActivation()
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (embed_out): Linear(in_features=512, out_features=50304, bias=False)
# )

# %% [markdown]
# ### Run slightly trained model

# %%
test_question = test_dataset[0]['question']
print("Question input (test):", test_question)

print("Finetuned slightly model's answer: ")
print(inference(test_question, finetuned_slightly_model, tokenizer))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Question input (test): Can Lamini generate technical documentation or user manuals for software projects?
# Finetuned slightly model's answer:
# Yes, Lamini can generate technical documentation or user manuals for software projects. It is recommended to consult the documentation for more information. Additionally, Lamini can generate technical documentation or user manuals for software projects. It is recommended to consult the documentation for more information. Additionally, Lamini can generate technical documentation or user manuals for software projects. It is recommended to consult the documentation for more information. Additionally

# %%
test_answer = test_dataset[0]['answer']
print("Target answer output (test):", test_answer)
# Out:
# Target answer output (test): Yes, Lamini can generate technical documentation and user manuals for software projects. It uses natural language generation techniques to create clear and concise documentation that is easy to understand for both technical and non-technical users. This can save developers a significant amount of time and effort in creating documentation, allowing them to focus on other aspects of their projects.

# %% [markdown]
# ### Run same model trained for two epochs

# %%
finetuned_longer_model = AutoModelForCausalLM.from_pretrained("lamini/lamini_docs_finetuned")
tokenizer = AutoTokenizer.from_pretrained("lamini/lamini_docs_finetuned")

finetuned_longer_model.to(device)
print("Finetuned longer model's answer: ")
print(inference(test_question, finetuned_longer_model, tokenizer))
# Out:
# config.json:   0%|          | 0.00/717 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/282M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/264 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Finetuned longer model's answer:
# Yes, Lamini can generate technical documentation or user manuals for software projects. This can be achieved by providing a prompt for a specific technical question or question to the LLM Engine, or by providing a prompt for a specific technical question or question. Additionally, Lamini can be trained on specific technical questions or questions to help users understand the process and provide feedback to the LLM Engine. Additionally, Lamini

# %% [markdown]
# ### Run much larger trained model and explore moderation

# %%
bigger_finetuned_model = BasicModelRunner(model_name_to_id["bigger_model_name"])
bigger_finetuned_output = bigger_finetuned_model(test_question)
print("Bigger (2.8B) finetuned model (test): ", bigger_finetuned_output)

# %%
count = 0
for i in range(len(train_dataset)):
 if "keep the discussion relevant to Lamini" in train_dataset[i]["answer"]:
  print(i, train_dataset[i]["question"], train_dataset[i]["answer"])
  count += 1
print(count)

# %% [markdown]
# ### Explore moderation using small model
# First, try the non-finetuned base model:

# %%
base_tokenizer = AutoTokenizer.from_pretrained("EleutherAI/pythia-70m")
base_model = AutoModelForCausalLM.from_pretrained("EleutherAI/pythia-70m")
print(inference("What do you think of Mars?", base_model, base_tokenizer))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# I think I’m going to go to the next page.
#
# I think I’m going to go to the next page.
#
# I think I’m going to go to the next page.
#
# I think I’m going to go to the next page.
#
# I think I’m going to go to the next page.
#
# I think I’m going to go to the next page.
#
# I

# %% [markdown]
# ### Now try moderation with finetuned small model

# %%
print(inference("What do you think of Mars?", finetuned_slightly_model, tokenizer))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Lamini is a language model for building AI systems. It uses a combination of natural language processing and machine learning to generate text. It uses a combination of natural language processing and machine learning to generate text. It uses a combination of natural language processing and machine learning to generate text. It uses a combination of natural language processing and machine learning to generate text. It uses a combination of natural language processing and machine learning to generate text. It uses a combination of natural

# %% [markdown]
# ### Finetune a model in 3 lines of code using Lamini

# %%
model = BasicModelRunner("EleutherAI/pythia-410m") 
model.load_data_from_jsonlines("lamini_docs.jsonl", input_key="question", output_key="answer")
model.train(is_public=True)

# %%
out = model.evaluate()

# %%
lofd = []
for e in out['eval_results']:
    q  = f"{e['input']}"
    at = f"{e['outputs'][0]['output']}"
    ab = f"{e['outputs'][1]['output']}"
    di = {'question': q, 'trained model': at, 'Base Model' : ab}
    lofd.append(di)
df = pd.DataFrame.from_dict(lofd)
style_df = df.style.set_properties(**{'text-align': 'left'})
style_df = style_df.set_properties(**{"vertical-align": "text-top"})
style_df
